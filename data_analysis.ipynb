# %% [markdown]
# # Bellabeat Data Analysis - Google Capstone Project

# %% [markdown]
# ### Case Study Description:
# The purpose of this case study is to tackle real-world tasks as a data analyst and deliver comprehensive solutions to crucial business inquiries by adhering to the 6-step data analysis process. These steps are ask, prepare, process, analyze, share, and act phases.

# %% [markdown]
# ### Business Task:
# Analyze the FitBit fitness tracker data to gain insights on how users interact with the FitBit app and discover trends that can be used to shape Bellabeat's marketing strategy.

# %% [markdown]
# ### Step 1. Ask Phase:
# Before proceeding, we need to identify our primary stakeholders. The situation involves the following stakeholders:
#
# Urška Sršen is the co-founder and Chief Creative Officer of Bellabeat, while Sando Mur is a mathematician and co-founder of Bellabeat, serving as a key member of the executive team.
#
# Bellabeat's marketing strategy is guided by a team of skilled data analysts who meticulously gather, scrutinize, and report data. Their insights are invaluable in shaping our marketing direction.

# %% [markdown]
# ### Business Objectives:
# - What are the current trends in smart device usage?
#
# - How might these trends apply to Bellabeat's customers?
#
# - In what ways can these trends impact Bellabeat's marketing strategy?

# %% [markdown]
# ### Step 2. Prepare Phase:
# Sršen suggested that I utilize openly accessible data that analyzes the everyday schedules of individuals who use smart devices. She directed me toward the subsequent dataset:
#
# The Mobius-hosted data set available on Kaggle under the CC0 Public Domain license consists of personal fitness tracker data from thirty Fitbit users who voluntarily disclosed their minute-by-minute heart rate, sleep, and physical activity monitoring information. The data encompasses details on daily activity, steps taken, and heart rate, enabling thorough analysis of users' routines.There are 18 CSV files available on Kaggle that contain data from the FitBit fitness tracker which can be accessed for free.
#
# During the Prepare step, we identify the data being utilized and its limitations.
#
# - The data was collected in 2016, which was seven years ago. As time has passed, users may have altered their daily routines, including their eating, exercise, and sleep habits. Therefore, the data may not be current or relevant.
#
# - It is not appropriate to assume that the entire fitness market can be accurately represented based on a sample size of only 30 FitBit users.
#
# - We cannot guarantee the accuracy or reliability of the data since it was collected through a survey.

# %% [markdown]
# ### Is Data ROCCC?
# ROCCC, an acronym for Reliable, Original, Comprehensive, Current, and Cited, serves as a dependable and trustworthy source of information.
#
# - Reliable — LOW — Having only 30 responders makes it unreliable.
#
# - Original — LOW — The service being referred to is provided by a third party, specifically Amazon Mechanical Turk.
#
# - Comprehensive — MED — The device's parameters align with those typically found in Bellabeat devices.
#
# - Current — LOW — Data that is 7 years old may no longer be applicable or significant.
#
# - Cited — LOW — The data was obtained from an unspecified third party. Overall, the dataset is considered to have poor-quality data, and it is not recommended to rely on it for making business recommendations.

# %% [markdown]
# ### Step 3. Process Phase:
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import plotly.graph_objs as go

# %% [markdown]
# Importing the data

# %%
daily_activity = pd.read_csv("dailyActivity_merged.csv")
sleep_per_day = pd.read_csv("sleepDay_merged.csv")
weight_log_info = pd.read_csv("weightLogInfo_merged.csv")

# %% [markdown]
# ### Quick Analysis of Data
# Daily Activity Dataset

# %%
daily_activity.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
daily_activity.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %% [markdown]
# Sleep Per Day Dataset

# %%
sleep_per_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_per_day.describe()
# Out:
#                  Id  TotalSleepRecords  TotalMinutesAsleep  TotalTimeInBed
# count  4.130000e+02         413.000000          413.000000      413.000000
# mean   5.000979e+09           1.118644          419.467312      458.639225
# std    2.060360e+09           0.345521          118.344679      127.101607
# min    1.503960e+09           1.000000           58.000000       61.000000
# 25%    3.977334e+09           1.000000          361.000000      403.000000
# 50%    4.702922e+09           1.000000          433.000000      463.000000
# 75%    6.962181e+09           1.000000          490.000000      526.000000
# max    8.792010e+09           3.000000          796.000000      961.000000

# %% [markdown]
# Weight Log Info Dataset

# %%
weight_log_info.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
weight_log_info.describe()
# Out:
#                  Id    WeightKg  WeightPounds       Fat        BMI  \
# count  6.700000e+01   67.000000     67.000000   2.00000  67.000000
# mean   7.009282e+09   72.035821    158.811801  23.50000  25.185224
# std    1.950322e+09   13.923206     30.695415   2.12132   3.066963
# min    1.503960e+09   52.599998    115.963147  22.00000  21.450001
# 25%    6.962181e+09   61.400002    135.363832  22.75000  23.959999
# 50%    6.962181e+09   62.500000    137.788914  23.50000  24.389999
# 75%    8.877689e+09   85.049999    187.503152  24.25000  25.559999
# max    8.877689e+09  133.500000    294.317120  25.00000  47.540001
#
#               LogId
# count  6.700000e+01
# mean   1.461772e+12
# std    7.829948e+08
# min    1.460444e+12
# 25%    1.461079e+12
# 50%    1.461802e+12
# 75%    1.462375e+12
# max    1.463098e+12

# %% [markdown]
# After executing these commands, we discovered the following:
#
# - The number of records and columns
# - The count of null and non-null values
# - The data type for each column
#
# We discovered 67 records in the weight log info, with 413 records for sleep per day and 940 records for daily activity data. Notably, the "Fat" variable in the weight log info contains null values, which can either be dropped or filled with the most common values. However, cleaning the data is not crucial for any other purpose. To optimize analysis, we transformed the date column from character format to datetime64 type and generated additional columns for the year, month, day, and day of the week.

# %%
daily_activity.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
# Change the data type from object to date
daily_activity['ActivityDate'] = pd.to_datetime(daily_activity['ActivityDate'], format='%m/%d/%Y')

# %%
daily_activity.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %%
# Create year column
daily_activity['Year'] = daily_activity['ActivityDate'].dt.year

# Create month column
daily_activity['Month'] = daily_activity['ActivityDate'].dt.month

# Create day column
daily_activity['Day'] = daily_activity['ActivityDate'].dt.day

# Create day_of_week column
daily_activity['Day_of_week'] = daily_activity['ActivityDate'].dt.day_name()

# %%
sleep_per_day.dtypes
# Out:
# Id                     int64
# SleepDay              object
# TotalSleepRecords      int64
# TotalMinutesAsleep     int64
# TotalTimeInBed         int64
# dtype: object

# %%
# Change the data type from object to date
sleep_per_day['SleepDay'] = pd.to_datetime(sleep_per_day['SleepDay'], format="%m/%d/%Y %I:%M:%S %p")

# %%
# Create year column
sleep_per_day['Year'] = sleep_per_day['SleepDay'].dt.year

# Create month column
sleep_per_day['Month'] = sleep_per_day['SleepDay'].dt.month

# Create day column
sleep_per_day['Day'] = sleep_per_day['SleepDay'].dt.day

# Create day_of_week column
sleep_per_day['Day_of_week'] = sleep_per_day['SleepDay'].dt.day_name()

# %%
sleep_per_day.head()
# Out:
#            Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366 2016-04-12                  1                 327
# 1  1503960366 2016-04-13                  2                 384
# 2  1503960366 2016-04-15                  1                 412
# 3  1503960366 2016-04-16                  2                 340
# 4  1503960366 2016-04-17                  1                 700
#
#    TotalTimeInBed  Year  Month  Day Day_of_week
# 0             346  2016      4   12     Tuesday
# 1             407  2016      4   13   Wednesday
# 2             442  2016      4   15      Friday
# 3             367  2016      4   16    Saturday
# 4             712  2016      4   17      Sunday

# %%
# Change the data type from object to date
weight_log_info['Date'] = pd.to_datetime(weight_log_info['Date'], format="%m/%d/%Y %I:%M:%S %p")

# %%
# Create year column
weight_log_info['Year'] = weight_log_info['Date'].dt.year

# Create month column
weight_log_info['Month'] = weight_log_info['Date'].dt.month

# Create day column
weight_log_info['Day'] = weight_log_info['Date'].dt.day

# Create day_of_week column
weight_log_info['Day_of_week'] = weight_log_info['Date'].dt.day_name()

# %%
weight_log_info.dtypes
# Out:
# Id                         int64
# Date              datetime64[ns]
# WeightKg                 float64
# WeightPounds             float64
# Fat                      float64
# BMI                      float64
# IsManualReport              bool
# LogId                      int64
# Year                       int64
# Month                      int64
# Day                        int64
# Day_of_week               object
# dtype: object

# %% [markdown]
# ### Fixing NA values
# To address the missing values, I will use the available data to fill them in. Alternatively, I suggest removing the 'Fat' variable as it does not provide any valuable insights.

# %%
weight_log_info['Fat'].unique()
# Out:
# array([22., nan, 25.])

# %%
import random

# Replace missing 'Fat' values with values between 22 and 25
weight_log_info['Fat'] = weight_log_info['Fat'].apply(lambda x: random.randint(22, 25))

# Check the updated value counts
print(weight_log_info['Fat'].value_counts())
# Out:
# 22    26
# 23    15
# 25    14
# 24    12
# Name: Fat, dtype: int64

# %% [markdown]
# ### Step 4. Analyze Phase:
# Daily Activity Dataset Correlations:

# %%
da_numeric_columns = daily_activity.select_dtypes(include='number')
daily_activity_corr = da_numeric_columns.corr()

plt.figure(figsize=(14, 10))
sns.heatmap(daily_activity_corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap - Daily Activity")
plt.show()

# %% [markdown]
# Histograms:

# %%
# Select columns for the histogram
columns_for_histogram = [
    'Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
    'LoggedActivitiesDistance', 'VeryActiveDistance',
    'ModeratelyActiveDistance', 'LightActiveDistance',
    'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
    'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories', 'Year', 'Month',
    'Day', 'Day_of_week'
]

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=len(columns_for_histogram), ncols=1, figsize=(8, 6 * len(columns_for_histogram)))

# Create histograms for each column
for i, col in enumerate(columns_for_histogram):
    sns.histplot(data=daily_activity, x=col, ax=axes[i], kde=True)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Sleep Per Day Dataset Correlations:

# %%
spd_numeric_columns = sleep_per_day.select_dtypes(include='number')
sleep_per_day_corr = spd_numeric_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(sleep_per_day_corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap - Sleep per Day")
plt.show()

# %% [markdown]
# Histograms:

# %%
# Select columns for the histogram
columns_for_histogram = [
    "Id", "SleepDay", "TotalSleepRecords", "TotalMinutesAsleep", "TotalTimeInBed", "Year", "Month", "Day", "Day_of_week"
]

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=len(columns_for_histogram), ncols=1, figsize=(8, 6 * len(columns_for_histogram)))

# Create histograms for each column
for i, col in enumerate(columns_for_histogram):
    sns.histplot(data=sleep_per_day, x=col, ax=axes[i], kde=True)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

# Adjust spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Weight Log Info Dataset Correlations:

# %%
wli_numeric_columns = weight_log_info.select_dtypes(include='number')
weight_log_info_corr = wli_numeric_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(weight_log_info_corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap - Weight Log Info")
plt.show()

# %% [markdown]
# Histograms:

# %%
# Select columns for the histogram
columns_for_histogram = [
    'Id', 'Date', 'WeightKg', 'WeightPounds', 'Fat', 'BMI',
    'IsManualReport', 'LogId', 'Year', 'Month', 'Day', 'Day_of_week'
]

# Create subplots for the histograms
fig, axes = plt.subplots(nrows=len(columns_for_histogram), ncols=1, figsize=(8, 6 * len(columns_for_histogram)))

# Create histograms for each column
for i, col in enumerate(columns_for_histogram):
    if weight_log_info[col].dtype == bool:
        # Convert boolean column to numeric
        weight_log_info[col] = weight_log_info[col].astype(int)

    sns.histplot(data=weight_log_info, x=col, ax=axes[i], kde=True)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

# Adjust spacing between subplots
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Findings:
# Daily Activity Dataset:
#
# - On average, users travel 5.490 km, which is below the required 8 km mark. Additionally, the average number of steps taken is 7638, which falls short of the target of 10000 steps.
#
# - Research has shown that the average user consumes around 2304 kCal daily.
#
# - People only achieve 21.16 highly active minutes per day, falling short of the recommended goal of 30 minutes per day.
#
# - On average, people spend 991.2 minutes or 16.52 hours being sedentary, which is significantly more than the recommended maximum of 7 hours.

# %% [markdown]
# Sleep Per Day Dataset:
#
# - The average user sleeps for a total of 419 minutes, or around 7 hours.
#
# - On average, people spend 458 minutes or 7 hours and 30 minutes in bed at night.
#
# - According to the two statements mentioned above, it seems that the typical user spends around 30 minutes awake in bed.

# %% [markdown]
# Weight Log Info Dataset:
# - It's important to consider factors beyond weight when evaluating someone's overall health. Variables like height and body fat percentage also play a role in determining their well-being.
#
# - On average, the body fat percentage of a typical user is 23.5%.
#
# - The healthy BMI range for good health is 18 to 24.9. However, the average BMI is 25.19, which is notably higher.
#
# - On average, users weigh about 72 kg which is equivalent to 158.8 pounds.

# %% [markdown]
# ### Step 5. Share Phase:
# In this step, I'll produce some visual aids based on our analysis and project goals.

# %%
# Set the order of the days of the week
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
daily_activity["Day_of_week"] = pd.Categorical(daily_activity["Day_of_week"], categories=day_order, ordered=True)

# Create the bar plot
plt.figure(figsize=(8, 6))
sns.countplot(x="Day_of_week", data=daily_activity, color='#0077b6')

# Set the labels and title
plt.xlabel("Day of Week")
plt.ylabel("Count")
plt.title("No. of times users used tracker across week")

# Show the plot
plt.show()

# %% [markdown]
# FitBit app usage is highest on Sundays, Mondays, and Tuesdays, possibly due to people being busier on weekends and having less time to monitor physical activity.

# %%
da_days = daily_activity.groupby('Day_of_week').agg({'TotalDistance': 'sum'}).reset_index().sort_values('TotalDistance', ascending=False)

fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x='Day_of_week', y='TotalDistance', data=da_days, color='#023e8a', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title('Total Distance During Each Day')
ax.set_ylabel('Total Distance Sum')
ax.set_xlabel('Days')

plt.show()

# %% [markdown]
# In contrast, we can observe that Tuesday, Wednesday, and Thursday have the highest total distance sum among all days. It is worth noting that Tuesday appears frequently in both charts, while Sunday and Monday have the lowest values.

# %%
mean_steps = daily_activity['TotalSteps'].mean()
mean_calories = daily_activity['Calories'].mean()

plt.figure(figsize=(12, 8))
palette = 'magma'
cmap = sns.color_palette(palette, as_cmap=True).reversed()

sns.scatterplot(data=daily_activity, x='TotalSteps', y='Calories', hue='Calories', palette=cmap)
plt.axhline(mean_calories, color='red', linewidth=1.0)
plt.axvline(mean_steps, color='blue', linewidth=1.0)
plt.text(10000, 500, 'Average Steps', rotation=90)
plt.text(29000, 2500, 'Average Calories')
plt.xlabel('Steps Taken')
plt.ylabel('Calories Burned')
plt.title('Calories burned for every step taken')

plt.show()

# %% [markdown]
# - The scatter plot indicates a positive correlation, despite a few outliers that deviate from the trend.
#
# - The data clearly shows a positive correlation between the number of steps taken and the amount of calories burned.

# %%
plt.figure(figsize=(12, 8))
palette = 'magma'
cmap = sns.color_palette(palette, as_cmap=True).reversed()

sns.scatterplot(data=daily_activity, x='TotalSteps', y='SedentaryMinutes', hue='Calories', palette=cmap)
sns.regplot(data=daily_activity, x='TotalSteps', y='SedentaryMinutes', scatter=False, color='green', lowess=True)
plt.xlabel('Total Steps')
plt.ylabel('Sedentary Minutes')
plt.title('Total Steps vs Sedentary Minutes')

plt.show()

# %% [markdown]
# - As the step count surpasses 10,000, the relationship between them remains fairly constant, despite being inverse for fewer steps.
#
# - I noticed that after taking 15000 steps, there was a slight shift towards a positive relationship between steps and sedentary minutes.

# %%
all_calories = daily_activity.groupby('ActivityDate', as_index=False)['Calories'].sum()

plt.figure(figsize=(20, 6))

plt.plot(all_calories['ActivityDate'], all_calories['Calories'])
plt.title('Daily Calories')
plt.xlabel('Date')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# - On average, a person burns approximately 75,000 calories per day.
#
# - Since May 5th, there has been a noticeable decrease in the number of calories burnt per day. This decrease became even more pronounced after May 9th.

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(data=sleep_per_day, x='TotalMinutesAsleep', y='TotalTimeInBed', color='#6930c3')
sns.regplot(data=sleep_per_day, x='TotalMinutesAsleep', y='TotalTimeInBed', color='red', scatter=False)
plt.xlabel('Total Minutes Asleep')
plt.ylabel('Total Time in Bed')
plt.title('Sleep Time vs Time in Bed')

plt.show()

# %% [markdown]
# - It is evident that there is a strong positive correlation between TotalMinutesAsleep and TotalTimeInBed. However, there are several outliers in the data present in the middle and top portions of the plot.
#
# - People who spend a lot of time in bed without sleeping are uncommon, and there could be various reasons for this.

# %%
sleep_per_day.columns
# Out:
# Index(['Id', 'SleepDay', 'TotalSleepRecords', 'TotalMinutesAsleep',
#        'TotalTimeInBed', 'Year', 'Month', 'Day', 'Day_of_week'],
#       dtype='object')

# %%
all_sleep = sleep_per_day.groupby('SleepDay', as_index=False)['TotalMinutesAsleep'].sum()

plt.figure(figsize=(20, 6))

plt.plot(all_sleep['SleepDay'], all_sleep['TotalMinutesAsleep'])
plt.title('Total Minutes As Sleep Each Day')
plt.xlabel('Date')
plt.ylabel('Minutes As Sleep')
plt.show()

# %% [markdown]
# - On Sundays, specifically April 24, May 1, and May 8, there are typically higher amounts of minutes spent sleeping.

# %%
spd_days = sleep_per_day.groupby('Day_of_week').agg({'TotalMinutesAsleep':'sum'}).reset_index().sort_values('TotalMinutesAsleep', ascending=False)

fig, ax = plt.subplots(figsize=(8, 6))
sns.barplot(x='Day_of_week', y='TotalMinutesAsleep', data=spd_days, color='#0077b6', ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_title('Total Sleep Minutes During Each Day')
ax.set_ylabel('Total Sleep Minutes Sum')
ax.set_xlabel('Days')

plt.show()

# %% [markdown]
# - Based on the data, it appears that Wednesday has the highest total sleeping minutes. However, this suggests that there may be additional factors not accounted for in the chart.

# %%
z = [5, 3]
piepercent = [round((100 * val) / sum(z), 1) for val in z]
colors = ['#b7094c', '#0091ad']

plt.pie(z, labels=[f'{percent}%' for percent in piepercent], explode=[0.1, 0], colors=colors, radius=1)
plt.title('Percentage of people with Over Weight vs Healthy Weight')
plt.legend(['Over Weight', 'Healthy Weight'], loc='lower left', fontsize='small', title='Legend', title_fontsize='small')

plt.show()

# %% [markdown]
# - More than 62% of individuals are considered overweight, while less than 38% are at a healthy weight. However, with effort and dedication, we can work towards making positive changes in this area.

# %%
x = [19895, 12751, 181244, 931738]
piepercent = [round((100 * val) / sum(x), 1) for val in x]
colors = ['#118ab2', '#ef476f', '#06d6a0', '#ffd166']

plt.pie(x, labels=[f'{percent}%' for percent in piepercent], colors=colors)
plt.title('Percentage of Activity in Minutes')
plt.legend(['Very Active Minutes', 'Fairly Active Minutes', 'Lightly Active Minutes', 'Sedentary Minutes'], loc='lower right', fontsize='small', title='Legend', title_fontsize='small')

plt.show()

# %% [markdown]
# - 81.3% of our time is spent being sedentary, meaning we have low levels of physical activity for long periods.
#
# - In comparison to other activities, the percentage of highly active and fairly active minutes is quite low, with only 1.7% and 1.1%, respectively.

# %%
y = [533.49, 3140.37, 1412.52]
piepercent = [round((100 * val) / sum(y), 1) for val in y]
colors = ['#086375', '#1dd3b0', '#affc41']

plt.pie(y, labels=[f'{percent}%' for percent in piepercent], colors=colors)
plt.title('Percentage of Activity in Minutes')
plt.legend(['Moderately Active Distance', 'Lightly Active Distance', 'Very Active Distance'], loc='lower left', fontsize='small', title='Legend', title_fontsize='small')

plt.show()

# %% [markdown]
# - The percentage for minimally active distance is the highest at 61.7%, while moderately active distance is at 10.5%.
#
# - While the percentage of people engaging in high levels of physical activity is decent at 27.8%, there is room for improvement in terms of assisting individuals in achieving their fitness goals.

# %% [markdown]
# ### Step 6. Act Phase:
# For the final step, I will provide my observations and recommendations based on the analysis. To do so, I will refer back to the initial business questions.

# %% [markdown]
# **What are the current trends in smart device usage?**
#
# - Based on our analysis, it was found that most individuals utilize applications to monitor their activity levels, calories burned, and sleep patterns. However, weight monitoring is not as popular. Therefore, I suggest prioritizing step, calorie, and sleep-tracking features in the application.
#
# - On average, users sit for 16 hours each day.
#
# - It's worth noting that users typically take around 7638 steps on an average day, which is below the recommended 10,000 steps.
#
# - On average, a user sleeps for approximately 7 hours, which is equivalent to 419 minutes. A typical night in bed lasts for 7 hours and 30 minutes, which is equal to 458 minutes. Based on these figures, it can be inferred that the average user spends around 30 minutes awake while in bed.
#
# **How might these trends apply to Bellabeat's customers?**
#
# - We have received detailed information from our female users. In contrast, FitBit provides products that help customers gain a better understanding of their sleep, activity, and overall health habits. This information is made accessible to encourage healthy practices. These insights are relevant to Bellabeat's user base, as they share similar characteristics.
#
# - It's worth noting that a significant 62.5% of individuals who use fitness trackers fall under the category of being obese. This highlights a tremendous opportunity to motivate people towards adopting a healthier lifestyle.
#
# **In what ways can these trends impact Bellabeat's marketing strategy?**
#
# - It has been observed that there is a direct connection between the number of steps taken and the number of calories burned, as well as between highly active minutes and calories burned. This information could be useful for marketing purposes.
#
# - As a helpful tool, Bellabeat can remind users periodically about their sedentary behavior through the application or tracker. This could be valuable information for marketing strategy as 81.3% of FitBit app users do not use it to track their health habits.
#
# - The Bellabeat marketing team aims to inspire and educate customers about the benefits of fitness through the Bellabeat app. They offer guidance on different workout options and provide details on calorie intake and burn rate to help users achieve their fitness goals.
